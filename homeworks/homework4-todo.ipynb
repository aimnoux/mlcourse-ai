# %% [markdown]
# ## <center> Домашнее задание №4. Обнаружение сарказма с помощью логистической регрессии
#
# Мы будем использовать датасет из [статьи](https://arxiv.org/abs/1704.05579) «A Large Self-Annotated Corpus for Sarcasm» с более чем 1 млн комментариев с Reddit, размеченных как саркастичные или нет. Обработанную версию можно найти на Kaggle в виде [Kaggle Dataset](https://www.kaggle.com/danofer/sarcasm).
#
# Обнаружить сарказм легко.
# <img src="https://habrastorage.org/webt/1f/0d/ta/1f0dtavsd14ncf17gbsy1cvoga4.jpeg" />

# %%
# необходимые импорты
import os
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
import seaborn as sns
from matplotlib import pyplot as plt

# %%
train_df = pd.concat([
    pd.read_csv('../data/train-balanced-sarcasm-part1.csv'),
    pd.read_csv('../data/train-balanced-sarcasm-part2.csv'),
    pd.read_csv('../data/train-balanced-sarcasm-part3.csv'),
], ignore_index=True)

# %%
train_df.head()

# %%
train_df.info()

# %% [markdown]
# Некоторые комментарии отсутствуют, поэтому удалим соответствующие строки.

# %%
train_df.dropna(subset=['comment'], inplace=True)

# %% [markdown]
# Видим, что датасет действительно сбалансирован.

# %%
train_df['label'].value_counts()

# %% [markdown]
# Разделим данные на обучающую и валидационную части.

# %%
train_texts, valid_texts, y_train, y_valid = \
        train_test_split(train_df['comment'], train_df['label'], random_state=17)

# %% [markdown]
# ## Задания:
# 1. Проанализируйте датасет, постройте визуализации.
# 2. Постройте пайплайн Tf-Idf + логистическая регрессия для предсказания сарказма (`label`) по тексту комментария на Reddit (`comment`).
# 3. Визуализируйте слова/биграммы, которые наиболее характерны для сарказма (можно использовать [eli5](https://github.com/TeamHG-Memex/eli5)).
# 4. (опционально) Добавьте сабреддиты как новые признаки для улучшения качества модели. Примените подход Bag of Words, т.е. каждый сабреддит — отдельный признак.
#
# ## Ссылки:
#   - Библиотека машинного обучения [Scikit-learn](https://scikit-learn.org/stable/index.html) (a.k.a. sklearn)
#   - [ELI5](https://github.com/TeamHG-Memex/eli5) для объяснения предсказаний модели
